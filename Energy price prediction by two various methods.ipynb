# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
energy_data = pd.read_csv('D:\Python\Github\dataset\Energy consumption\energy_dataset.csv')
energy_data.to_csv('price_data_new.csv',columns=['price actual'])

New_data = pd.read_csv('price_data_new.csv')


#slice_rows & columns
#New_data = New_data.iloc[26306:]


#modeling_DecisionTreeRegressor

X = New_data.drop(['price actual'], axis=1)
y = New_data['price actual']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#print(X)
#print(y)

#Predictions on Testing data
DT_model = DecisionTreeRegressor(max_depth=20).fit(X_train,y_train)
DT_predict = DT_model.predict(X_test) 

print(DT_predict)
print(y_test.values)
plt.plot(y_test.values, 'r')
plt.plot(DT_predict)
#predictions=model.predict(X_test)
#score = accuracy_score(y_test.values, DT_predict)
#score
# Out:
# [45.38 83.26 65.25 ... 36.07 25.36 38.54]
# [43.68 76.09 62.15 ... 41.36 23.93 37.57]

# %%
#Building the KNN Model 
from sklearn.neighbors import KNeighborsRegressor

#modeling_DecisionTreeRegressor

X = New_data.drop(['price actual'], axis=1)
y = New_data['price actual']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#Predictions on Testing data
KNN_model = KNeighborsRegressor(n_neighbors=5).fit(X_train,y_train)
KNN_predict = KNN_model.predict(X_test) 
print(KNN_predict)
print(y_test.values)
plt.plot(y_test.values, 'r')
plt.plot(KNN_predict)
# Out:
# [69.37  78.854 69.826 ... 64.992 55.71  68.59 ]
# [69.74 77.9  76.22 ... 69.6  53.25 69.85]

# %%
#Building new dataset
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import accuracy_score
import numpy as np
from numpy import mean
from numpy import std
from numpy import cov
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
New_data = pd.read_csv('price_data_new.csv')
new_data_Jan2015= New_data.iloc[2:745]
new_data_Jan2016= New_data.iloc[8762:9505]

new_data_Jan2015 = new_data_Jan2015.drop(columns= new_data_Jan2015.columns[0])
new_data_Jan2016 = new_data_Jan2016.drop(columns= new_data_Jan2016.columns[0])
#print(new_data_Jan2016)
plt.title("Scatter Diagram")
plt.xlabel("Price Data JAN.2015")
plt.ylabel("Price Data JAN.2016")
plt.scatter(new_data_Jan2015, new_data_Jan2016)
plt.show()


print('new_data_Jan2015: mean=%.3f stdv=%.3f' % (mean(new_data_Jan2015), std(new_data_Jan2015)))
print('new_data_Jan2016: mean=%.3f stdv=%.3f' % (mean(new_data_Jan2016), std(new_data_Jan2016)))

#X = new_data_Jan2015.drop(['price actual'], axis=1)
#print(X)
#y = new_data_Jan2015['price actual']
X_train, X_test, y_train, y_test = train_test_split(new_data_Jan2015, new_data_Jan2015, test_size=0.2)

#Predictions on Testing data
KNN_model = KNeighborsRegressor(n_neighbors=5).fit(X_train,y_train)
KNN_predict = KNN_model.predict(X_test) 
KNN_predict2016 = KNN_model.predict(new_data_Jan2016) 

plt.plot(new_data_Jan2016.values, 'r')
plt.plot(KNN_predict2016)

plt.title("Comparison Forcast (blue line) and Actual (red line) Energy Price")
plt.show()
# Out:
# new_data_Jan2015: mean=64.899 stdv=15.494
# new_data_Jan2016: mean=45.555 stdv=13.398
